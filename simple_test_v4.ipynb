# %%
import time 
import torch
import psycopg2
from transformers import AutoTokenizer, AutoModelForCausalLM
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage
import os
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Test database connection

# %%
def test_db_connection():
    """Test database connection and print table information."""
    try:
        conn = psycopg2.connect(
            dbname="test_db_val",
            user="postgres",
            password=os.environ.get("POSTGRES_PASSWORD"),
            host="localhost"
        )
        cur = conn.cursor()
        
        # Get counts for relevant tables
        tables = [
            'professional_details',
            'professional_locations',
            'languages_spoken_by_professional',
            'professional_availabilities',
            'professional_areas_of_interest',
            'age_group_professional_works_with',
            'type_of_funding_accepted'
        ]
        
        print("\nTable row counts:")
        for table in tables:
            try:
                cur.execute(f"SELECT COUNT(*) FROM {table}")
                count = cur.fetchone()[0]
                print(f"{table}: {count} rows")
            except Exception as e:
                print(f"Error querying {table}: {e}")
        
        # Test a simple join query
        print("\nTesting sample join query:")
        cur.execute("""
            SELECT 
                pd.persona, 
                COUNT(*) as count
            FROM professional_details pd
            GROUP BY pd.persona;
        """)
        
        results = cur.fetchall()
        print("\nProfessionals by type:")
        for persona, count in results:
            print(f"{persona}: {count}")
            
        conn.close()
        print("\nDatabase connection test successful!")
        return True
        
    except Exception as e:
        print(f"Database connection failed: {e}")
        return False

if __name__ == "__main__":
    import os
    from dotenv import load_dotenv
    import psycopg2
    
    load_dotenv()
    test_db_connection()
# Out:
# Table row counts:
# professional_details: 7018 rows
# professional_locations: 9782 rows
# languages_spoken_by_professional: 6177 rows
# professional_availabilities: 1507 rows
# professional_areas_of_interest: 6164 rows
# age_group_professional_works_with: 6164 rows
# type_of_funding_accepted: 6164 rows
#
# Testing sample join query:
#
# Professionals by type:
# Occupational Therapist: 2696
# Speech pathologist: 2615
# Psychologist: 1707
#
# Database connection test successful!

# %%
# Add your OpenAI API key here
openai_api_key = os.environ.get("OPENAI_API_KEY")

# Updated schema context matching actual database
schema_context = """
You are a SQL expert. Generate PostgreSQL queries for a healthcare professional database with the following schema:

Tables and their key columns:
1. professional_details
   - professional_id (PK, varchar)
   - first_name (varchar)
   - last_name (varchar)
   - persona (varchar)
   - email (varchar)
   - phone_number (varchar)
   - additional_phone_numbers (text)
   - summary (text)
   - about (text)
   - telepractice_offered (boolean)
   - mobile_services_offered (boolean)
   - mobile_services_areas (text)

2. professional_locations
   - id (PK, integer)
   - professional_id (FK, varchar)
   - location (geometry)
   - city_suburb (text)
   - state_region (text)
   - postcode (text)
   - latitude (double precision)
   - longitude (double precision)
   - formatted_address (text)

3. languages_spoken_by_professional
   - professional_id (FK, varchar)
   - Mandarin (boolean)
   - English (boolean)
   - [plus many other language columns, all boolean]

4. professional_availabilities
   - id (PK, integer)
   - professional_id (FK, varchar)
   - availability_notes (text)
   - immediate (boolean)
   - within_1_month (boolean)
   - within_3_months (boolean)
   - within_6_months (boolean)
   - within_12_months (boolean)
   - more_than_12_months (boolean)
   - last_updated (timestamp with time zone)

5. professional_areas_of_interest
   - professional_id (FK, varchar)
   - Autism (boolean)
   - Disability (boolean)
   - Mental_Health (boolean)
   - Anxiety (boolean)
   - Depression (boolean)
   - [plus many other specialty columns, all boolean]

6. age_group_professional_works_with
   - professional_id (FK, varchar)
   - infants (boolean)
   - pre_school_children (boolean)
   - school_aged_children (boolean)
   - adolescents (boolean)
   - adults (boolean)
   - aged (boolean)

7. type_of_funding_accepted
   - professional_id (FK, varchar)
   - ndis_registered (boolean)
   - ndis_non_registered (boolean)
   - medicare (boolean)
   - private_health_insurance (boolean)
   - department_of_veterans_affairs (boolean)
   - workers_compensation (boolean)

Important Notes:
- All tables use professional_id as their link to professional_details
- Location queries can use either:
  * direct latitude/longitude comparison
  * OR PostGIS functions like ST_DWithin(ST_SetSRID(ST_MakePoint(long, lat), 4326), location, distance_meters)
- For name searches, use the similarity() function
- Check availability using multiple time window columns (immediate, within_1_month, etc.)
- Always include relevant contact and location details in results where appropriate
"""

def load_local_model(model_name_or_path):
    tokenizer = AutoTokenizer.from_pretrained(model_name_or_path)
    model = AutoModelForCausalLM.from_pretrained(model_name_or_path, torch_dtype=torch.float16)
    return model, tokenizer

def generate_sql_with_local_model(model, tokenizer, prompt):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    
    # Combine schema context with prompt
    full_prompt = f"{schema_context}\n\nWrite a PostgreSQL query to: {prompt}\n\nReturn ONLY the SQL query, no explanations or markdown."
    
    try:
        inputs = tokenizer(full_prompt, return_tensors="pt").to(device)
        
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_new_tokens=500,
                pad_token_id=tokenizer.eos_token_id,
                temperature=0.7,  # Add some randomness
                top_p=0.9,       # Nucleus sampling
                do_sample=True   # Enable sampling
            )
        
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        
        # Extract just the SQL query part
        response = response.split(full_prompt)[-1].strip()
        
        # Clean up the response
        response = response.replace('```sql', '').replace('```', '').strip()
        
        # Verify it looks like SQL
        if not any(keyword in response.lower() for keyword in ['select', 'from', 'where']):
            return "SELECT 'Error: No valid SQL generated'"
            
        model.to("cpu")
        torch.cuda.empty_cache()
        return response
        
    except Exception as e:
        return f"SELECT 'Error: {str(e)}'"

def generate_sql_with_openai_model(prompt):
    openai_model = ChatOpenAI(model="gpt-4o", api_key=openai_api_key)
    full_prompt = f"{schema_context}\n\nWrite a PostgreSQL query to: {prompt}\n\nReturn ONLY the SQL query, no explanations."
    response = openai_model([HumanMessage(content=full_prompt)])
    return response.content

def evaluate_query(query, expected_elements):
    """Evaluate a SQL query by checking syntax and expected elements."""
    if not query or not isinstance(query, str):
        return 0, ["✗ No valid query generated"]
        
    score = 0
    comments = []
    
    try:
        # Clean the query - remove any markdown code blocks if present
        query = query.strip()
        query = query.replace('```sql', '').replace('```', '')
        query = query.lower()
        
        # Check if it looks like SQL
        if not any(keyword in query for keyword in ['select', 'from', 'where']):
            return 0, ["✗ Response does not appear to be SQL"]
            
        # Check for expected elements
        total_elements = len(expected_elements)
        for element in expected_elements:
            if element.lower() in query:
                score += 1
                comments.append(f"✓ Contains {element}")
            else:
                comments.append(f"✗ Missing {element}")
        
        # Try to validate SQL syntax if sqlparse is available
        try:
            import sqlparse
            parsed = sqlparse.parse(query)
            if parsed:
                comments.append("✓ Valid SQL syntax")
            else:
                comments.append("✗ Invalid SQL syntax")
        except ImportError:
            comments.append("⚠ SQL syntax validation skipped (sqlparse not available)")
            
        return score / total_elements, comments
        
    except Exception as e:
        return 0, [f"✗ Error evaluating query: {str(e)}"]

def compare_models(models, test_cases):
    results = {}
    results_data = []
    
    for model_name, (model, tokenizer) in models.items():
        print(f"\nTesting model: {model_name}")
        
        for test_case in test_cases:
            print(f"\nRunning test case: {test_case['name']}")
            start_time = time.time()
            
            try:
                response = generate_sql_with_local_model(model, tokenizer, test_case['prompt'])
                response_time = time.time() - start_time
                score, comments = evaluate_query(response, test_case['expected_elements'])
                
                results_data.append({
                    'Model': model_name,
                    'Test Case': test_case['name'],
                    'Response Time': f"{response_time:.2f}s",
                    'Score': f"{score:.2%}",
                    'Comments': '\n'.join(comments),
                    'Generated Query': response
                })
                
                print(f"Generated SQL:\n{response}")
                print(f"Score: {score:.2%}")
                print(f"Response time: {response_time:.2f} seconds")
                print("Comments:\n" + '\n'.join(comments))
            except Exception as e:
                print(f"Error testing model {model_name} on case {test_case['name']}: {str(e)}")

    # Test OpenAI model
    print("\nTesting OpenAI model")
    for test_case in test_cases:
        print(f"\nRunning test case: {test_case['name']}")
        start_time = time.time()
        
        try:
            openai_response = generate_sql_with_openai_model(test_case['prompt'])
            openai_response_time = time.time() - start_time
            score, comments = evaluate_query(openai_response, test_case['expected_elements'])
            
            results_data.append({
                'Model': 'OpenAI GPT-4',
                'Test Case': test_case['name'],
                'Response Time': f"{openai_response_time:.2f}s",
                'Score': f"{score:.2%}",
                'Comments': '\n'.join(comments),
                'Generated Query': openai_response
            })
            
            print(f"Generated SQL:\n{openai_response}")
            print(f"Score: {score:.2%}")
            print(f"Response time: {openai_response_time:.2f} seconds")
            print("Comments:\n" + '\n'.join(comments))
        except Exception as e:
            print(f"Error testing OpenAI model on case {test_case['name']}: {str(e)}")

    # Convert results to DataFrame and calculate summary
    results_df = pd.DataFrame(results_data)
    results_df['Score'] = results_df['Score'].str.rstrip('%').astype(float) / 100

    # Display summary
    print("\nResults Summary:")
    summary_df = results_df.pivot_table(
        index='Model',
        values='Score',
        columns='Test Case',
        aggfunc='first'
    ).round(2)

    print("\nAverage Scores by Model:")
    print(summary_df.mean(axis=1).sort_values(ascending=False))

    # Save detailed results
    results_df.to_csv('sql_model_comparison_results.csv', index=False)
    
    return results_df

# %%
# Updated test cases based on actual schema
test_cases = [
    {
        'name': 'Geolocation Search',
        'prompt': 'find speech therapists within 5000 meters of Northcote, Melbourne (coordinates: -37.7692917, 144.9990291). Include their names, contact details, and distance. Sort by distance.',
        'expected_elements': [
            'professional_details',
            'professional_locations',
            'latitude',
            'longitude',
            'persona = \'Speech pathologist\'',
            'JOIN',
            'ORDER BY'
        ]
    },
    {
        'name': 'Immediate Availability',
        'prompt': 'find therapists who are immediately available or within 1 month AND offer telepractice. Include their names, contact details, and availability notes.',
        'expected_elements': [
            'professional_details',
            'professional_availabilities',
            'immediate = TRUE',
            'within_1_month = TRUE',
            'telepractice_offered = TRUE',
            'availability_notes',
            'JOIN'
        ]
    },
    {
        'name': 'Language and Mental Health',
        'prompt': 'find all psychologists who speak Mandarin AND specialize in anxiety or depression. Include their contact details and areas of interest.',
        'expected_elements': [
            'professional_details',
            'languages_spoken_by_professional',
            'professional_areas_of_interest',
            'Mandarin = TRUE',
            'anxiety = TRUE',
            'depression = TRUE',
            'persona = \'Psychologist\'',
            'JOIN'
        ]
    },
    {
        'name': 'Complex Age and Funding',
        'prompt': 'find occupational therapists who work with school-aged children AND accept both NDIS and Medicare funding AND offer mobile services. Include their location and contact details.',
        'expected_elements': [
            'professional_details',
            'age_group_professional_works_with',
            'type_of_funding_accepted',
            'school_aged_children = TRUE',
            'ndis_registered = TRUE',
            'medicare = TRUE',
            'mobile_services_offered = TRUE',
            'JOIN'
        ]
    },
    {
        'name': 'Full Profile Search',
        'prompt': 'get the complete profile for therapist "John Smith", including their contact details, availability, languages spoken, areas of interest, age groups they work with, and funding types accepted.',
        'expected_elements': [
            'professional_details',
            'professional_availabilities',
            'languages_spoken_by_professional',
            'professional_areas_of_interest',
            'age_group_professional_works_with',
            'type_of_funding_accepted',
            'similarity',
            'LEFT JOIN'
        ]
    },
    {
        'name': 'Advanced Availability Search',
        'prompt': 'find speech pathologists in Melbourne who work with children, are available within 3 months, and either offer telepractice or mobile services. Sort by earliest availability.',
        'expected_elements': [
            'professional_details',
            'professional_locations',
            'professional_availabilities',
            'age_group_professional_works_with',
            'within_3_months = TRUE',
            'telepractice_offered = TRUE',
            'mobile_services_offered = TRUE',
            'ORDER BY'
        ]
    }
]

# Define your models
local_models = {
   # "NumbersStation/nsql-llama-2-7B": load_local_model("NumbersStation/nsql-llama-2-7B"),
    "defog/llama-3-sqlcoder-8B": load_local_model("defog/llama-3-sqlcoder-8B"),
    #"defog/sqlcoder-7b-2": load_local_model("defog/sqlcoder-7b-2"),
    #"Llama-3.2-1B-Instruct": load_local_model("meta-llama/Llama-3.2-1B-Instruct"),
    "Llama-3.2-3B-Instruct": load_local_model("meta-llama/Llama-3.2-3B-Instruct")
}

# Run comparison and display results
results_df = compare_models(local_models, test_cases)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# c:\Users\User\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:590: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# c:\Users\User\anaconda3\Lib\site-packages\transformers\generation\configuration_utils.py:590: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Testing model: defog/llama-3-sqlcoder-8B
#
# Running test case: Geolocation Search
# Generated SQL:
# SELECT pd.first_name, pd.last_name, pl.formatted_address, pl.latitude, pl.longitude, ST_Distance(pl.location, ST_SetSRID(ST_MakePoint(-37.7692917, 144.9990291), 4326)) AS distance FROM professional_details pd JOIN professional_locations pl ON pd.professional_id = pl.professional_id WHERE ST_DWithin(pl.location, ST_SetSRID(ST_MakePoint(-37.7692917, 144.9990291), 4326), 5000) AND pl.city_suburb = 'Northcote' AND pl.state_region = 'Melbourne' AND pd.telepractice_offered = FALSE AND pd.mobile_services_offered = FALSE ORDER BY distance;
# Score: 85.71%
# Response time: 321.02 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains professional_locations
# ✓ Contains latitude
# ✓ Contains longitude
# ✗ Missing persona = 'Speech pathologist'
# ✓ Contains JOIN
# ✓ Contains ORDER BY
# ✓ Valid SQL syntax
#
# Running test case: Immediate Availability
# Generated SQL:
# SELECT p.first_name, p.last_name, p.email, p.phone_number, p.additional_phone_numbers, pa.availability_notes FROM professional_details p JOIN professional_availabilities pa ON p.professional_id = pa.professional_id WHERE (pa.immediate = TRUE OR pa.within_1_month = TRUE) AND p.telepractice_offered = TRUE ORDER BY p.first_name NULLS LAST, p.last_name NULLS LAST;
# Score: 100.00%
# Response time: 72.73 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains professional_availabilities
# ✓ Contains immediate = TRUE
# ✓ Contains within_1_month = TRUE
# ✓ Contains telepractice_offered = TRUE
# ✓ Contains availability_notes
# ✓ Contains JOIN
# ✓ Valid SQL syntax
#
# Running test case: Language and Mental Health
# Generated SQL:
# SELECT p.first_name, p.last_name, p.email, p.phone_number, pl.location, pl.formatted_address, pl.postcode, pl.city_suburb, pl.state_region, pl.latitude, pl.longitude, pl.id AS location_id, l.Mandarin AS speaks_mandarin, a.Anxiety AS specializes_in_anxiety, d.Depression AS specializes_in_depression FROM professional_details p JOIN professional_locations pl ON p.professional_id = pl.professional_id JOIN languages_spoken_by_professional l ON p.professional_id = l.professional_id JOIN professional_areas_of_interest a ON p.professional_id = a.professional_id JOIN professional_areas_of_interest d ON p.professional_id = d.professional_id WHERE l.Mandarin = TRUE AND (a.Anxiety = TRUE OR d.Depression = TRUE);
# Score: 87.50%
# Response time: 69.90 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains languages_spoken_by_professional
# ✓ Contains professional_areas_of_interest
# ✓ Contains Mandarin = TRUE
# ✓ Contains anxiety = TRUE
# ✓ Contains depression = TRUE
# ✗ Missing persona = 'Psychologist'
# ✓ Contains JOIN
# ✓ Valid SQL syntax
#
# Running test case: Complex Age and Funding
# Generated SQL:
# SELECT pd.first_name, pd.last_name, pl.formatted_address, pd.phone_number, pd.email, tfa.ndis_registered, tfa.medicare FROM professional_details pd JOIN professional_locations pl ON pd.professional_id = pl.professional_id JOIN type_of_funding_accepted tfa ON pd.professional_id = tfa.professional_id WHERE (age_group_professional_works_with.infants = FALSE AND age_group_professional_works_with.pre_school_children = FALSE AND age_group_professional_works_with.adolescents = FALSE AND age_group_professional_works_with.adults = FALSE AND age_group_professional_works_with.aged = FALSE AND age_group_professional_works_with.school_aged_children = TRUE) AND tfa.ndis_registered = TRUE AND tfa.medicare = TRUE AND mobile_services_offered = TRUE;
# Score: 100.00%
# Response time: 110.78 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains age_group_professional_works_with
# ✓ Contains type_of_funding_accepted
# ✓ Contains school_aged_children = TRUE
# ✓ Contains ndis_registered = TRUE
# ✓ Contains medicare = TRUE
# ✓ Contains mobile_services_offered = TRUE
# ✓ Contains JOIN
# ✓ Valid SQL syntax
#
# Running test case: Full Profile Search
# Generated SQL:
# SELECT p.first_name, p.last_name, p.email, p.phone_number, p.additional_phone_numbers, pl.city_suburb, pl.state_region, pl.postcode, pl.formatted_address, pa.availability_notes, pl.latitude, pl.longitude, ls.Mandarin, ls.English, ao.Autism, ao.Disability, ao.Mental_Health, ao.Anxiety, ao.Depression, ag.infants, ag.pre_school_children, ag.school_aged_children, ag.adolescents, ag.adults, ag.aged, tf.ndis_registered, tf.ndis_non_registered, tf.medicare, tf.private_health_insurance, tf.department_of_veterans_affairs, tf.workers_compensation FROM professional_details p JOIN professional_locations pl ON p.professional_id = pl.professional_id JOIN professional_availabilities pa ON p.professional_id = pa.professional_id JOIN languages_spoken_by_professional ls ON p.professional_id = ls.professional_id JOIN professional_areas_of_interest ao ON p.professional_id = ao.professional_id JOIN age_group_professional_works_with ag ON p.professional_id = ag.professional_id JOIN type_of_funding_accepted tf ON p.professional_id = tf.professional_id WHERE p.first_name ilike '%John%' AND p.last_name ilike '%Smith%'
# Score: 75.00%
# Response time: 263.89 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains professional_availabilities
# ✓ Contains languages_spoken_by_professional
# ✓ Contains professional_areas_of_interest
# ✓ Contains age_group_professional_works_with
# ✓ Contains type_of_funding_accepted
# ✗ Missing similarity
# ✗ Missing LEFT JOIN
# ✓ Valid SQL syntax
#
# Running test case: Advanced Availability Search
# Generated SQL:
# SELECT pd.first_name, pd.last_name, pl.location, pa.availability_notes, pa.last_updated FROM professional_details pd JOIN professional_locations pl ON pd.professional_id = pl.professional_id JOIN professional_areas_of_interest pa ON pd.professional_id = pa.professional_id WHERE pa.infants = TRUE AND pa.pre_school_children = TRUE AND pa.school_aged_children = TRUE AND pa.adolescents = TRUE AND (pd.telepractice_offered = TRUE OR pd.mobile_services_offered = TRUE) AND (pa.within_3_months = TRUE OR pa.within_6_months = TRUE) ORDER BY pa.last_updated ASC;
# Score: 75.00%
# Response time: 72.00 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains professional_locations
# ✗ Missing professional_availabilities
# ✗ Missing age_group_professional_works_with
# ✓ Contains within_3_months = TRUE
# ✓ Contains telepractice_offered = TRUE
# ✓ Contains mobile_services_offered = TRUE
# ✓ Contains ORDER BY
# ✓ Valid SQL syntax
#
# Testing model: Llama-3.2-3B-Instruct
#
# Running test case: Geolocation Search
# Generated SQL:
# SELECT
#     p.first_name,
#     p.last_name,
#     p.email,
#     p.phone_number,
#     p.additional_phone_numbers,
#     p.summary,
#     p.about,
#     p.telepractice_offered,
#     p.mobile_services_offered,
#     p.mobile_services_areas,
#     (ST_Distance(p.location, ST_SetSRID(ST_MakePoint(-37.7692917, 144.9990291), 4326)) / 1000) AS distance_meters,
#     ST_Distance(p.location, ST_SetSRID(ST_MakePoint(-37.7692917, 144.9990291), 4326)) AS distance_km
# FROM
#     professional_details p
# JOIN
#     professional_locations pl ON p.professional_id = pl.professional_id
# WHERE
#     ST_DWithin(pl.location, ST_SetSRID(ST_MakePoint(-37.7692917, 144.9990291), 4326), 5000) OR
#     ST_DWithin(pl.location, ST_SetSRID(ST_MakePoint(-37.7692917, 144.9990291), 4326), 5000, 'interior')
#
#
#
# SELECT
#     p.first_name,
#     p.last_name,
#     p.email,
#     p.phone_number,
#     p.additional_phone_numbers,
#     p.summary,
#     p.about,
#     p.telepractice_offered,
#     p.mobile_services_offered,
#     p.mobile_services_areas,
#     ST_Distance(p.location, ST_SetSRID(ST_MakePoint(-37.7692917, 144.9990291), 4326)) AS distance_meters,
#     ST_Distance(p.location, ST_SetSRID(ST_MakePoint(-37.7692917, 144.9990291), 4326)) AS distance_km
# FROM
#     professional_details p
# JOIN
#     professional_locations pl ON p.professional_id = pl.professional_id
# WHERE
#     ST_DWithin(pl.location, ST_SetSRID(ST_MakePoint(-37.7692917, 144.9990291), 4326), 5000)
#
#
#
# SELECT
#     p.first_name,
#     p.last_name,
#     p.email,
#     p.phone_number,
#     p.additional_phone_numbers,
#     p.summary,
#     p.about,
#     p.telepractice_offered,
#     p.mobile_services_offered,
#     p
# Score: 42.86%
# Response time: 729.55 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains professional_locations
# ✗ Missing latitude
# ✗ Missing longitude
# ✗ Missing persona = 'Speech pathologist'
# ✓ Contains JOIN
# ✗ Missing ORDER BY
# ✓ Valid SQL syntax
#
# Running test case: Immediate Availability
# Generated SQL:
# SELECT
#     p.first_name,
#     p.last_name,
#     p.email,
#     p.phone_number,
#     p.additional_phone_numbers,
#     p.summary,
#     p.about,
#     tta.availability_notes,
#     tta.immediate,
#     tta.within_1_month,
#     tta.within_3_months,
#     tta.within_6_months,
#     tta.within_12_months,
#     tta.more_than_12_months
# FROM
#     professional_details p
# JOIN
#     professional_availabilities tta ON p.professional_id = tta.professional_id
# JOIN
#     professional_areas_of_interest paro ON p.professional_id = paro.professional_id
# JOIN
#     professional_locations pl ON p.professional_id = pl.professional_id
# WHERE
#     tta.immediate OR tta.within_1_month OR tta.within_3_months OR tta.within_6_months OR tta.within_12_months
# AND
#     paro.Telepractice_offered = TRUE
# AND
#     pl.location ST_DWithin(ST_SetSRID(ST_MakePoint(0, 0), 4326), ST_MakePoint(pl.longitude, pl.latitude), 10);
#
#
# Note: The query may not return results if the location query does not match.
# Score: 71.43%
# Response time: 82.09 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains professional_availabilities
# ✗ Missing immediate = TRUE
# ✗ Missing within_1_month = TRUE
# ✓ Contains telepractice_offered = TRUE
# ✓ Contains availability_notes
# ✓ Contains JOIN
# ✓ Valid SQL syntax
#
# Running test case: Language and Mental Health
# Generated SQL:
# SELECT
#     p.first_name,
#     p.last_name,
#     pd.persona,
#     p.email,
#     p.phone_number,
#     p.additional_phone_numbers,
#     p.summary,
#     p.about,
#     p.telepractice_offered,
#     p.mobile_services_offered,
#     p.mobile_services_areas,
#     l.location,
#     l.city_suburb,
#     l.state_region,
#     l.postcode,
#     l.latitude,
#     l.longitude,
#     l.formatted_address,
#     ...
# Score: 0.00%
# Response time: 89.27 seconds
# Comments:
# ✗ Missing professional_details
# ✗ Missing languages_spoken_by_professional
# ✗ Missing professional_areas_of_interest
# ✗ Missing Mandarin = TRUE
# ✗ Missing anxiety = TRUE
# ✗ Missing depression = TRUE
# ✗ Missing persona = 'Psychologist'
# ✗ Missing JOIN
# ✓ Valid SQL syntax
#
# Running test case: Complex Age and Funding
# Generated SQL:
# SELECT
#   pd.first_name,
#   pd.last_name,
#   pl.location,
#   pd.email,
#   pd.phone_number,
#   pd.additional_phone_numbers,
#   pl.city_suburb,
#   pl.state_region,
#   pl.postcode,
#   pl.latitude,
#   pl.longitude,
#   pl.formatted_address
# FROM
#   professional_details pd
# JOIN
#   professional_locations pl ON pd.professional_id = pl.professional_id
# WHERE
#   pd.professional_id IN (
#     SELECT
#       professional_id
#     FROM
#       professional_areas_of_interest
#     WHERE
#       professional_id IN (
#         SELECT
#           professional_id
#         FROM
#           age_group_professional_works_with
#         WHERE
#           professional_id IN (
#             SELECT
#               professional_id
#             FROM
#               professional_areas_of_interest
#             WHERE
#               professional_id IN (
#                 SELECT
#                   professional_id
#                 FROM
#                   professional_details
#                 WHERE
#                   professional_id IN (
#                     SELECT
#                       professional_id
#                     FROM
#                       professional_areas_of_interest
#                     WHERE
#                       professional_id IN (
#                         SELECT
#                           professional_id
#                         FROM
#                           professional_details
#                         WHERE
#                           professional_id IN (
#                             SELECT
#                               professional_id
#                             FROM
#                               professional_areas_of_interest
#                             WHERE
#                               professional_id = 'your_professional_id'
#                             )
#                           )
#                         )
#                       )
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#
#
# Note: Replace `'your_professional_id'` with your desired professional_id. Replace `age_group_professional_works_with` with actual table name in your database.
#
#
# -- Corrected Query
# SELECT
#   pd.first_name,
#   pd.last_name,
#   ST_AsGeoJSON(pl.location).features[0].geometry,
#   pd.email,
#   pd.phone_number,
#   pd.additional_phone_numbers,
#   pl.city_suburb,
#   pl.state_region,
#   pl.postcode,
#   pl.latitude,
#   pl.longitude,
#   pl.formatted_address
# FROM
#   professional_details pd
# JOIN
#   professional_locations pl ON pd.professional_id = pl.professional_id
# WHERE
#   pd.professional_id IN (
#     SELECT
#       professional_id
#     FROM
#       professional_areas_of_interest
#     WHERE
#       professional_id IN (
#         SELECT
#           professional_id
# Score: 37.50%
# Response time: 96.04 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains age_group_professional_works_with
# ✗ Missing type_of_funding_accepted
# ✗ Missing school_aged_children = TRUE
# ✗ Missing ndis_registered = TRUE
# ✗ Missing medicare = TRUE
# ✗ Missing mobile_services_offered = TRUE
# ✓ Contains JOIN
# ✓ Valid SQL syntax
#
# Running test case: Full Profile Search
# Generated SQL:
# SELECT
#   pd.first_name,
#   pd.last_name,
#   pd.persona,
#   pd.email,
#   pd.phone_number,
#   pd.additional_phone_numbers,
#   pd.summary,
#   pd.about,
#   pl.location,
#   pl.city_suburb,
#   pl.state_region,
#   pl.postcode,
#   pl.latitude,
#   pl.longitude,
#   pl.formatted_address,
#   ls.mandarin,
#   ls.english,
#   ls.autism,
#   ls.disability,
#   ls.mental_health,
#   ls.anxiety,
#   ls.depression,
#   pa.immediate,
#   pa.within_1_month,
#   pa.within_3_months,
#   pa.within_6_months,
#   pa.within_12_months,
#   pa.more_than_12_months,
#   ls.last_updated,
#   pa.last_updated,
#   ap.autism,
#   ap.disability,
#   ap.mental_health,
#   ap.anxiety,
#   ap.depression,
#   ag.infants,
#   ag.pre_school_children,
#   ag.school_aged_children,
#   ag.adults,
#   ag.aged,
#   tp.ndis_registered,
#   tp.ndis_non_registered,
#   tp.medicare,
#   tp.private_health_insurance,
#   tp.department_of_veterans_affairs,
#   tp.workers_compensation
# FROM
#   professional_details pd
#   JOIN professional_locations pl ON pd.professional_id = pl.professional_id
#   JOIN languages_spoken_by_professional ls ON pd.professional_id = ls.professional_id
#   JOIN professional_areas_of_interest ap ON pd.professional_id = ap.professional_id
#   JOIN age_group_professional_works_with ag ON pd.professional_id = ag.professional_id
#   JOIN type_of_funding_accepted tp ON pd.professional_id = tp.professional_id
# WHERE
#   pd.first_name = 'John'
#   AND pd.last_name = 'Smith'
#   AND pl.latitude = 37.7749
#   AND pl.longitude = -122.4194
#   AND ls.mandarin = TRUE
#   AND ap.autism = TRUE
#   AND ag.infants = TRUE
#   AND tp.ndis_registered = TRUE
#   AND tp.ndis_non_registered = FALSE
# Score: 62.50%
# Response time: 48.54 seconds
# Comments:
# ✓ Contains professional_details
# ✗ Missing professional_availabilities
# ✓ Contains languages_spoken_by_professional
# ✓ Contains professional_areas_of_interest
# ✓ Contains age_group_professional_works_with
# ✓ Contains type_of_funding_accepted
# ✗ Missing similarity
# ✗ Missing LEFT JOIN
# ✓ Valid SQL syntax
#
# Running test case: Advanced Availability Search
# Generated SQL:
# SELECT *
# FROM professional_details
# JOIN professional_locations
# JOIN professional_availabilities
# JOIN professional_areas_of_interest
# JOIN age_group_professional_works_with
# JOIN type_of_funding_accepted
# WHERE
#   professional_details.persona = 'Speech Pathologist'
#   AND professional_details.email LIKE '%@health.vic.gov.au'
#   AND professional_locations.city_suburb = 'Melbourne'
#   AND professional_areas_of_interest.school_aged_children = TRUE
#   AND professional_availabilities.within_3_months = TRUE
#   AND (professional_details.telepractice_offered = TRUE OR professional_details.mobile_services_offered = TRUE)
# ORDER BY professional_availabilities.last_updated DESC;
#
#
#
# SELECT *
# FROM professional_details
# JOIN professional_locations
# JOIN professional_availabilities
# JOIN professional_areas_of_interest
# JOIN age_group_professional_works_with
# JOIN type_of_funding_accepted
# WHERE
#   professional_details.persona = 'Speech Pathologist'
#   AND professional_details.email LIKE '%@health.vic.gov.au'
#   AND professional_locations.city_suburb = 'Melbourne'
#   AND professional_areas_of_interest.school_aged_children = TRUE
#   AND professional_availabilities.within_3_months = TRUE
#   AND (professional_details.telepractice_offered = TRUE OR professional_details.mobile_services_offered = TRUE)
# ORDER BY professional_availabilities.last_updated DESC;
#
#
#
# SELECT *
# FROM professional_details
# JOIN professional_locations
# JOIN professional_availabilities
# JOIN professional_areas_of_interest
# JOIN age_group_professional_works_with
# JOIN type_of_funding_accepted
# WHERE
#   professional_details.persona = 'Speech Pathologist'
#   AND professional_details.email LIKE '%@health.vic.gov.au'
#   AND professional_locations.city_suburb = 'Melbourne'
#   AND professional_areas_of_interest.school_aged_children = TRUE
#   AND professional_availabilities.within_3_months = TRUE
#   AND (professional_details.telepractice_offered = TRUE OR professional_details.mobile_services_offered = TRUE)
# ORDER BY professional_availabilities.last_updated DESC;
#
#
#
# SELECT *
# FROM professional_details
# JOIN professional_locations
# JOIN professional_availabilities
# JOIN professional_areas_of_interest
# JOIN age_group_professional_works_with
# JOIN type_of_funding_accepted
# WHERE
#   professional_details.persona = 'Speech Pathologist'
#   AND professional_details.email LIKE '%@health.vic.gov.au'
#   AND professional_locations.city_suburb = 'Melbourne'
#   AND professional_areas_of
# Score: 100.00%
# Response time: 52.50 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains professional_locations
# ✓ Contains professional_availabilities
# ✓ Contains age_group_professional_works_with
# ✓ Contains within_3_months = TRUE
# ✓ Contains telepractice_offered = TRUE
# ✓ Contains mobile_services_offered = TRUE
# ✓ Contains ORDER BY
# ✓ Valid SQL syntax
#
# Testing OpenAI model
#
# Running test case: Geolocation Search
# C:\Users\User\AppData\Local\Temp\ipykernel_12764\2366661486.py:134: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   openai_model = ChatOpenAI(model="gpt-4o", api_key=openai_api_key)
# C:\Users\User\AppData\Local\Temp\ipykernel_12764\2366661486.py:136: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = openai_model([HumanMessage(content=full_prompt)])
# Generated SQL:
# ```sql
# SELECT
#     pd.first_name,
#     pd.last_name,
#     pd.email,
#     pd.phone_number,
#     pd.additional_phone_numbers,
#     pd.telepractice_offered,
#     pd.mobile_services_offered,
#     pd.mobile_services_areas,
#     pl.formatted_address,
#     pl.city_suburb,
#     pl.state_region,
#     pl.postcode,
#     pl.latitude,
#     pl.longitude,
#     ST_Distance(
#         ST_SetSRID(ST_MakePoint(144.9990291, -37.7692917), 4326)::geography,
#         pl.location::geography
#     ) AS distance_meters
# FROM
#     professional_details pd
# JOIN
#     professional_locations pl ON pd.professional_id = pl.professional_id
# WHERE
#     pd.persona ILIKE '%speech therapist%' AND
#     ST_DWithin(
#         ST_SetSRID(ST_MakePoint(144.9990291, -37.7692917), 4326)::geography,
#         pl.location::geography,
#         5000
#     )
# ORDER BY
#     distance_meters;
# ```
# Score: 85.71%
# Response time: 6.28 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains professional_locations
# ✓ Contains latitude
# ✓ Contains longitude
# ✗ Missing persona = 'Speech pathologist'
# ✓ Contains JOIN
# ✓ Contains ORDER BY
# ✓ Valid SQL syntax
#
# Running test case: Immediate Availability
# Generated SQL:
# ```sql
# SELECT pd.first_name, pd.last_name, pd.email, pd.phone_number, pa.availability_notes
# FROM professional_details pd
# JOIN professional_availabilities pa ON pd.professional_id = pa.professional_id
# WHERE pa.immediate = TRUE OR pa.within_1_month = TRUE
# AND pd.telepractice_offered = TRUE;
# ```
# Score: 100.00%
# Response time: 1.90 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains professional_availabilities
# ✓ Contains immediate = TRUE
# ✓ Contains within_1_month = TRUE
# ✓ Contains telepractice_offered = TRUE
# ✓ Contains availability_notes
# ✓ Contains JOIN
# ✓ Valid SQL syntax
#
# Running test case: Language and Mental Health
# Generated SQL:
# ```sql
# SELECT
#     pd.professional_id,
#     pd.first_name,
#     pd.last_name,
#     pd.email,
#     pd.phone_number,
#     pd.additional_phone_numbers,
#     pd.summary,
#     pd.about,
#     pd.telepractice_offered,
#     pd.mobile_services_offered,
#     pd.mobile_services_areas,
#     pla.Mandarin,
#     pai.Anxiety,
#     pai.Depression
# FROM
#     professional_details pd
# JOIN
#     languages_spoken_by_professional pla ON pd.professional_id = pla.professional_id
# JOIN
#     professional_areas_of_interest pai ON pd.professional_id = pai.professional_id
# WHERE
#     pd.persona = 'Psychologist'
#     AND pla.Mandarin = TRUE
#     AND (pai.Anxiety = TRUE OR pai.Depression = TRUE);
# ```
# Score: 100.00%
# Response time: 3.04 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains languages_spoken_by_professional
# ✓ Contains professional_areas_of_interest
# ✓ Contains Mandarin = TRUE
# ✓ Contains anxiety = TRUE
# ✓ Contains depression = TRUE
# ✓ Contains persona = 'Psychologist'
# ✓ Contains JOIN
# ✓ Valid SQL syntax
#
# Running test case: Complex Age and Funding
# Generated SQL:
# ```sql
# SELECT
#     pd.professional_id,
#     pd.first_name,
#     pd.last_name,
#     pd.email,
#     pd.phone_number,
#     pd.mobile_services_areas,
#     pl.formatted_address,
#     pl.city_suburb,
#     pl.state_region,
#     pl.postcode
# FROM
#     professional_details pd
# JOIN
#     age_group_professional_works_with ag ON pd.professional_id = ag.professional_id
# JOIN
#     type_of_funding_accepted tf ON pd.professional_id = tf.professional_id
# JOIN
#     professional_locations pl ON pd.professional_id = pl.professional_id
# WHERE
#     pd.persona = 'Occupational Therapist'
#     AND ag.school_aged_children = TRUE
#     AND tf.ndis_registered = TRUE
#     AND tf.medicare = TRUE
#     AND pd.mobile_services_offered = TRUE;
# ```
# Score: 100.00%
# Response time: 2.89 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains age_group_professional_works_with
# ✓ Contains type_of_funding_accepted
# ✓ Contains school_aged_children = TRUE
# ✓ Contains ndis_registered = TRUE
# ✓ Contains medicare = TRUE
# ✓ Contains mobile_services_offered = TRUE
# ✓ Contains JOIN
# ✓ Valid SQL syntax
#
# Running test case: Full Profile Search
# Generated SQL:
# ```sql
# SELECT
#     pd.professional_id,
#     pd.first_name,
#     pd.last_name,
#     pd.persona,
#     pd.email,
#     pd.phone_number,
#     pd.additional_phone_numbers,
#     pd.summary,
#     pd.about,
#     pd.telepractice_offered,
#     pd.mobile_services_offered,
#     pd.mobile_services_areas,
#     pl.location,
#     pl.city_suburb,
#     pl.state_region,
#     pl.postcode,
#     pl.latitude,
#     pl.longitude,
#     pl.formatted_address,
#     pav.availability_notes,
#     pav.immediate,
#     pav.within_1_month,
#     pav.within_3_months,
#     pav.within_6_months,
#     pav.within_12_months,
#     pav.more_than_12_months,
#     pav.last_updated,
#     lsp.*,
#     paoi.*,
#     agpw.*,
#     tofa.*
# FROM
#     professional_details pd
# JOIN
#     professional_locations pl ON pd.professional_id = pl.professional_id
# JOIN
#     professional_availabilities pav ON pd.professional_id = pav.professional_id
# JOIN
#     languages_spoken_by_professional lsp ON pd.professional_id = lsp.professional_id
# JOIN
#     professional_areas_of_interest paoi ON pd.professional_id = paoi.professional_id
# JOIN
#     age_group_professional_works_with agpw ON pd.professional_id = agpw.professional_id
# JOIN
#     type_of_funding_accepted tofa ON pd.professional_id = tofa.professional_id
# WHERE
#     similarity(pd.first_name || ' ' || pd.last_name, 'John Smith') > 0.4;
# ```
# Score: 87.50%
# Response time: 6.60 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains professional_availabilities
# ✓ Contains languages_spoken_by_professional
# ✓ Contains professional_areas_of_interest
# ✓ Contains age_group_professional_works_with
# ✓ Contains type_of_funding_accepted
# ✓ Contains similarity
# ✗ Missing LEFT JOIN
# ✓ Valid SQL syntax
#
# Running test case: Advanced Availability Search
# Generated SQL:
# ```sql
# SELECT pd.professional_id, pd.first_name, pd.last_name, pd.email, pd.phone_number,
#        pl.formatted_address, pa.immediate, pa.within_1_month, pa.within_3_months, pa.last_updated
# FROM professional_details pd
# JOIN professional_locations pl ON pd.professional_id = pl.professional_id
# JOIN age_group_professional_works_with agpw ON pd.professional_id = agpw.professional_id
# JOIN professional_availabilities pa ON pd.professional_id = pa.professional_id
# WHERE pd.persona = 'Speech Pathologist'
#   AND pl.city_suburb = 'Melbourne'
#   AND (agpw.pre_school_children = TRUE OR agpw.school_aged_children = TRUE)
#   AND (pa.immediate = TRUE OR pa.within_1_month = TRUE OR pa.within_3_months = TRUE)
#   AND (pd.telepractice_offered = TRUE OR pd.mobile_services_offered = TRUE)
# ORDER BY pa.immediate DESC, pa.within_1_month DESC, pa.within_3_months DESC, pa.last_updated ASC;
# ```
# Score: 100.00%
# Response time: 4.92 seconds
# Comments:
# ✓ Contains professional_details
# ✓ Contains professional_locations
# ✓ Contains professional_availabilities
# ✓ Contains age_group_professional_works_with
# ✓ Contains within_3_months = TRUE
# ✓ Contains telepractice_offered = TRUE
# ✓ Contains mobile_services_offered = TRUE
# ✓ Contains ORDER BY
# ✓ Valid SQL syntax
#
# Results Summary:
#
# Average Scores by Model:
# Model
# OpenAI GPT-4                 0.956667
# defog/llama-3-sqlcoder-8B    0.873333
# Llama-3.2-3B-Instruct        0.523333
# dtype: float64

# %% [markdown]
# ### Summary of Model Performance
#
# | Model Name                       | Query Accuracy & Completeness                                                                                                                | Response Time (seconds) | Evaluation Summary                                 |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------|--------------------------|---------------------------------------------------|
# | **OpenAI GPT-4**                 | Highly accurate; produced valid SQL queries with comprehensive filtering, ordering, and essential elements.                                 | 1.90 - 6.60             | Fastest and most reliable for accurate SQL.       |
# | **defog/llama-3-sqlcoder-8B**    | Highly accurate; generated correct SQL queries with key elements like `JOIN`, `latitude/longitude`, and filtering logic.                    | 69.90 - 321.02          | Excellent accuracy but slower for complex queries.|
# | **Llama-3.2-3B-Instruct**        | Partially correct; handled complex cases better than smaller models, but some essential elements were missing.                              | 48.54 - 729.55          | Improved completeness but slow for larger queries.|
#
# ### Evaluation Summary
#
# 1. **Best Accuracy and Speed**:
#    - **OpenAI GPT-4** excelled in both accuracy and response time, delivering complete and accurate queries in under 7 seconds for most test cases.
#
# 2. **Best for Detailed and Accurate Results**:
#    - **defog/llama-3-sqlcoder-8B** achieved high accuracy and handled complex filters and joins well but had longer response times.
#
# 3. **Moderate Accuracy with Slower Performance**:
#    - **Llama-3.2-3B-Instruct** performed moderately well with some correct filters and structure but often missed critical components, resulting in slower performance.
#
# ### Recommendations
#
# - **For Optimal Accuracy and Efficiency**: **OpenAI GPT-4** is the preferred choice due to its balance of speed and accuracy in generating SQL queries.
# - **For High Precision in Detailed Queries**: **defog/llama-3-sqlcoder-8B** is suitable when detailed accuracy is prioritized over response time.
# - **Avoid**: Models with lower completeness and accuracy for SQL generation as they may lack essential elements and logic.
